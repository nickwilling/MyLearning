# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib as mlp
import scipy

# %%
data = pd.read_csv(r"D:\想毕业吗\火灾文件\火灾数据集\sdc14.csv")

# %%
data.head()
# Out:
#    'TIME  '  'TCA_1 '  'TCA_2 '  'TCA_3 '  'TCA_4 '  'TCA_5 '  'TCA_6 '  \
# 0   -1414.0     27.74     27.74     27.55     27.43     26.56     26.13
# 1   -1412.0     27.80     27.86     27.61     27.43     26.56     26.13
# 2   -1410.0     27.74     27.80     27.61     27.43     26.56     26.19
# 3   -1408.0     27.74     27.74     27.55     27.43     26.56     26.25
# 4   -1406.0     27.74     27.74     27.61     27.43     26.56     26.25
#
#    'TCA_7 '  'TCB_1 '  'TCB_2 '  ...  'SMCO  '  'Ion1A '  'Ion1C '  'Ion1D '  \
# 0     25.76     27.24     27.36  ...       0.0     5.349     6.368     6.219
# 1     25.82     27.24     27.37  ...       0.0     5.371     6.346     6.197
# 2     25.76     27.24     27.37  ...       0.0     5.373     6.390     6.210
# 3     25.76     27.24     27.37  ...       0.0     5.354     6.383     6.189
# 4     25.76     27.24     27.30  ...       0.0     5.363     6.386     6.221
#
#    'Ion1BE'  'DiPho2'  'DiIon2'  'DiIon4'  'Load  '  'TCRef '
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2814 entries, 0 to 2813
# Columns: 112 entries, 'TIME  ' to 'TCRef '
# dtypes: float64(112)
# memory usage: 2.4 MB

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.plot(data.iloc[:,0],data.iloc[:,1],linewidth=1,label='TCA 1')
plt.xlim((0,4500))
plt.ylim((28,34))
plt.xlabel('Time/s')
plt.ylabel('Temperature/C')
plt.title('Temperature. remote bedroom. 300 mm from ceiling')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(data.iloc[:,0],data.iloc[:,8],linewidth=1,label='TCB 1')
plt.xlim((0,4500))
plt.ylim((0,400))
plt.xlabel('Time/s')
plt.ylabel('Temperature/C')
plt.title('Temperature. main bedroom. 20 mm from ceiling')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(data.iloc[:,0],data.iloc[:,15],linewidth=1,label='TCC 1')
plt.xlim((0,4500))
plt.ylim((26,42))
plt.xlabel('Time/s')
plt.ylabel('Temperature/C')
plt.title('Temperature. hallway outside remote bedroom. 20 mm from ceiling')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(data.iloc[:,0],data.iloc[:,22],linewidth=1,label='TCD 1')
plt.xlim((0,4500))
plt.ylim((25,70))
plt.xlabel('Time/s')
plt.ylabel('Temperature/C')
plt.title('Temperature. living room. 20 mm from ceiling')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(data.iloc[:,0],data.iloc[:,29],linewidth=2,label='TCE 1')
plt.xlim((0,4500))
plt.ylim((27,36))
plt.xlabel('Time/s')
plt.ylabel('Temperature/C')
plt.title('Temperature. front door hallway. 20 mm from ceiling')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(data.iloc[:,0],data.iloc[:,36],linewidth=1,label='TCF 1')
plt.xlim((0,4500))
plt.ylim((25,60))
plt.xlabel('Time/s')
plt.ylabel('Temperature/C')
plt.title('Temperature. front door hallway. 20 mm from ceiling')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(data.iloc[:,0],data.iloc[:,43],linewidth=1,label='TCG')
plt.xlim((0,4500))
plt.ylim((24.4,25.4))
plt.xlabel('Time/s')
plt.ylabel('Temperature/C')
plt.title('Temperature. closed room')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(data.iloc[:,0],data.iloc[:,44],linewidth=1,label='TCFire')
plt.xlim((0,4500))
# plt.ylim((24.4,25.4))
plt.xlabel('Time/s')
plt.ylabel('Temperature/C')
plt.title('Temperature. directly above ignition point')
plt.legend()
plt.show()

# %%
# TCRef是什么
plt.figure()
# plt.plot(data.iloc[:,0],data.iloc[:,45],linewidth=1,label='TCRef')
# plt.xlim((0,4500))
# plt.xlabel('Time/s')
# plt.ylabel('Temperature/mV')
# plt.title('Temperature at data acquisition system')
# plt.legend()
plt.show()

# %% [markdown]
# ## Smoke Obscuration

# %%
plt.figure()
plt.plot(data.iloc[:,0],data.iloc[:,45],linewidth=1,label='SMA 1')
plt.xlim((0,4500))
plt.xlabel('Time/s')
plt.ylabel('SMA/1/m')
plt.title('Smoke Obscuration. remote bedroom. 20 mm from ceiling')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(data.iloc[:,0],data.iloc[:,47],linewidth=1,label='SMC 4')
plt.xlim((0,4500))
plt.xlabel('Time/s')
plt.ylabel('SMA/1/m')
plt.title('Smoke Obscuration. hallway outside remote bedroom. 900 mm from ceiling')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(data.iloc[:,0],data.iloc[:,48],linewidth=1,label='SMD 1')
plt.xlim((0,4500))
plt.xlabel('Time/s')
plt.ylabel('SMA/1/m')
plt.title('Smoke Obscuration. hallway outside main bedroom. 20 mm from ceiling')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(data.iloc[:,0],data.iloc[:,50],linewidth=1,label='SMF 1')
plt.xlim((0,4500))
plt.xlabel('Time/s')
plt.ylabel('SMA/1/m')
plt.title('Smoke Obscuration. front door hallway. 20 mm from ceiling')
plt.legend()
plt.show()

# %% [markdown]
# ## CO Concentration

# %%
# plt.figure()
# plt.plot(data.iloc[:,0],data.iloc[:,52],linewidth=1,label='SMCO')
# plt.xlim((0,4500))
# plt.xlabel('Time/s')
# plt.ylabel('CO/mV')
# plt.title('Carbon Dioxide concentration. remote bedroom')
# plt.legend()
# plt.show()

# %% [markdown]
# ## CO2 Concentration

# %%
plt.figure()
plt.plot(data.iloc[:,0],data.iloc[:,52],linewidth=1,label='GASA 1')
plt.xlim((0,4500))
plt.xlabel('Time/s')
plt.ylabel('CO2/vol')
plt.title('Carbon Dioxide concentration. remote bedroom')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(data.iloc[:,0],data.iloc[:,55],linewidth=1,label='GASC 1')
plt.xlim((0,4500))
plt.xlabel('Time/s')
plt.ylabel('CO2/vol')
plt.title('Carbon Dioxide concentration. hallway outside remote bedroom.')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(data.iloc[:,0],data.iloc[:,58],linewidth=1,label='GASF 1')
plt.xlim((0,4500))
plt.xlabel('Time/s')
plt.ylabel('CO2/vol')
plt.title('Carbon Dioxide concentration. front door hallway.')
plt.legend()
plt.show()

# %% [markdown]
# ## O2 Concentration

# %%
plt.figure()
plt.plot(data.iloc[:,0],data.iloc[:,61],linewidth=1,label='GASB 1  O2')
plt.xlim((0,4500))
plt.xlabel('Time/s')
plt.ylabel('O2/%')
plt.title('Oxygen concentration. remote bedroom.')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(data.iloc[:,0],data.iloc[:,53],linewidth=1,label='GASA 3  O2')
plt.xlim((0,4500))
plt.xlabel('Time/s')
plt.ylabel('O2/%')
plt.title('Oxygen concentration. hallway outside remote bedroom')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(data.iloc[:,0],data.iloc[:,56],linewidth=1,label='GASC 3  O2')
plt.xlim((0,4500))
plt.xlabel('Time/s')
plt.ylabel('O2/%')
plt.title('Oxygen concentration. front door hallway. ')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(data.iloc[:,0],data.iloc[:,59],linewidth=1,label='GASF 3  O2')
plt.xlim((0,4500))
plt.xlabel('Time/s')
plt.ylabel('O2/%')
plt.title('Oxygen concentration. main bedroom.')
plt.legend()
plt.show()

# %% [markdown]
# ## Smoke Alarm

# %%
plt.figure()
plt.plot(data.iloc[:,0],data.iloc[:,62],linewidth=1,label='Carbon Monoxide Alarm')
plt.xlim((0,4500))
plt.xlabel('Time/s')
plt.ylabel('GASB 3 (vol)')
plt.title('Carbon Monoxide Alarm 2. hallway outside remote bedroom')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(data.iloc[:,0],data.iloc[:,54],linewidth=1,label='Ionization Smoke Alarm')
plt.xlim((0,4500))
plt.xlabel('Time/s')
plt.ylabel('GASA 5 (vol)')
plt.title('Ionization Smoke Alarm 3. hallway outside remote bedroom')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(data.iloc[:,0],data.iloc[:,57],linewidth=1,label='Photoelectric Smoke Alarm')
plt.xlim((0,4500))
plt.xlabel('Time/s')
plt.ylabel('GASC 5 (vol)')
plt.title('Photoelectric Smoke Alarm 1. hallway outside remote bedroom')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(data.iloc[:,0],data.iloc[:,60],linewidth=1,label='Carbon Monoxide Alarm')
plt.xlim((0,4500))
plt.xlabel('Time/s')
plt.ylabel('GASF 5 (vol)')
plt.title('Carbon Monoxide Alarm 3. hallway outside remote bedroom')
plt.legend()
plt.show()
